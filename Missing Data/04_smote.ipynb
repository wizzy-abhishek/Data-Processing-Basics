# %%
from sklearn.datasets import make_classification

# %%
x, y = make_classification(
    n_samples=1000, n_redundant=0, n_features=2, n_clusters_per_class=1, random_state=10, weights=[0.90])

# %%
import pandas as pd

df1 = pd.DataFrame(x, columns=['f1','f2'])
df2 = pd.DataFrame(y, columns=['target'])

df = pd.concat([df1, df2], axis= 1)
df
# Out:
#            f1        f2  target
# 0    1.451220 -1.086705       0
# 1   -0.090861 -2.277740       1
# 2    1.918052 -1.043149       0
# 3    1.389333 -1.253164       0
# 4   -1.479985 -0.316676       1
# ..        ...       ...     ...
# 995  0.196916 -1.154123       0
# 996  0.869515 -1.147480       0
# 997  0.836751 -0.541619       0
# 998  0.457830 -1.051771       0
# 999  0.278917 -1.163092       0
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df['f1'], df['f2'], c=df.target)

# %%
from imblearn.over_sampling import SMOTE

oversample = SMOTE()
x,y = oversample.fit_resample(df[['f1','f2']], df['target'])

# %%
df1 = pd.DataFrame(x, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])

df = pd.concat([df1,df2], axis=1)
df
# Out:
#             f1        f2  target
# 0     1.451220 -1.086705       0
# 1    -0.090861 -2.277740       1
# 2     1.918052 -1.043149       0
# 3     1.389333 -1.253164       0
# 4    -1.479985 -0.316676       1
# ...        ...       ...     ...
# 1789  2.487561 -1.043799       1
# 1790 -0.991505 -1.063963       1
# 1791 -1.658694 -0.154033       1
# 1792  2.811621 -1.416888       1
# 1793 -0.741527 -1.438313       1
#
# [1794 rows x 3 columns]

# %%
plt.scatter(df['f1'], df['f2'], c=df.target)

# %%
df[df['target'] == 1]
# Out:
#             f1        f2  target
# 1    -0.090861 -2.277740       1
# 4    -1.479985 -0.316676       1
# 13   -0.165785 -2.208638       1
# 34   -2.500111  1.001949       1
# 37   -1.357267 -0.307103       1
# ...        ...       ...     ...
# 1789  2.487561 -1.043799       1
# 1790 -0.991505 -1.063963       1
# 1791 -1.658694 -0.154033       1
# 1792  2.811621 -1.416888       1
# 1793 -0.741527 -1.438313       1
#
# [897 rows x 3 columns]

# %%
df[df['target'] == 0]
# Out:
#            f1        f2  target
# 0    1.451220 -1.086705       0
# 2    1.918052 -1.043149       0
# 3    1.389333 -1.253164       0
# 5    1.995523 -1.463693       0
# 6    1.165560 -1.572988       0
# ..        ...       ...     ...
# 995  0.196916 -1.154123       0
# 996  0.869515 -1.147480       0
# 997  0.836751 -0.541619       0
# 998  0.457830 -1.051771       0
# 999  0.278917 -1.163092       0
#
# [897 rows x 3 columns]
