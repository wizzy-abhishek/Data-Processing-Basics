# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('height_weight_linear_data.csv')
df.head(2)
# Out:
#    Height  Weight
# 0  174.97    82.1
# 1  168.62    81.3

# %%
df.corr()
# Out:
#           Height    Weight
# Height  1.000000  0.866428
# Weight  0.866428  1.000000

# %%
plt.scatter(df['Weight'], df['Height'])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')
