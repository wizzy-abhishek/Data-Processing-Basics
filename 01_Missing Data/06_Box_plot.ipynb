# %%
import seaborn as sns

list_ages = [1,2,4,33,12,143,24,156,2,10,14,25,15,44,2,104,21,45,27,36,20,18,56,72]

sns.boxplot(list_ages)
# Out:
# <Axes: >
